# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !git clone https://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@github.com/Valerie9696/pythonProject
# Out:
# Cloning into 'pythonProject'...
# remote: Enumerating objects: 135, done.
# remote: Counting objects: 100% (135/135), done.
# remote: Compressing objects: 100% (77/77), done.
# remote: Total 135 (delta 68), reused 119 (delta 52), pack-reused 0
# Receiving objects: 100% (135/135), 7.08 MiB | 16.78 MiB/s, done.
# Resolving deltas: 100% (68/68), done.

# %%
# %cd pythonProject/
# Out:
# /kaggle/working/pythonProject

# %%
# !python script_hyperparam_opt.py ohlc output yes
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Using output folder output
# Selecting GPU ID=0
# ### Running hyperparameter optimization for ohlc ###
# Loading & splitting data...
# Formatting train-valid-test splits.
# Setting scalers with training data...
# *** Loading hyperparm manager ***
# Loading results from output/saved_models/ohlc/main
# Creating new hyperparameter optimisation
# *** Running calibration ***
# # Running hyperparam optimisation 1 of 60 for TFT
# Resetting temp folder...
# *** TemporalFusionTransformer params ***
# # dropout_rate = 0.3
# # hidden_layer_size = 40
# # learning_rate = 0.001
# # max_gradient_norm = 0.01
# # minibatch_size = 256
# # num_heads = 4
# # stack_size = 1
# # total_time_steps = 257
# # num_encoder_steps = 252
# # num_epochs = 100
# # early_stopping_patience = 5
# # multiprocessing_workers = 5
# # column_definition = [('Symbol', <DataTypes.CATEGORICAL: 1>, <InputTypes.ID: 4>), ('Datetime', <DataTypes.DATE: 2>, <InputTypes.TIME: 5>), ('Open', <DataTypes.REAL_VALUED: 0>, <InputTypes.OBSERVED_INPUT: 1>), ('High', <DataTypes.REAL_VALUED: 0>, <InputTypes.OBSERVED_INPUT: 1>), ('Low', <DataTypes.REAL_VALUED: 0>, <InputTypes.OBSERVED_INPUT: 1>), ('HighLowDifference', <DataTypes.REAL_VALUED: 0>, <InputTypes.OBSERVED_INPUT: 1>), ('OpenCloseDifference', <DataTypes.REAL_VALUED: 0>, <InputTypes.OBSERVED_INPUT: 1>), ('ATR', <DataTypes.REAL_VALUED: 0>, <InputTypes.OBSERVED_INPUT: 1>), ('RSI', <DataTypes.REAL_VALUED: 0>, <InputTypes.OBSERVED_INPUT: 1>), ('Close', <DataTypes.REAL_VALUED: 0>, <InputTypes.TARGET: 0>), ('HoursFromStart', <DataTypes.REAL_VALUED: 0>, <InputTypes.KNOWN_INPUT: 2>), ('HourOfDay', <DataTypes.CATEGORICAL: 1>, <InputTypes.KNOWN_INPUT: 2>), ('DayOfWeek', <DataTypes.CATEGORICAL: 1>, <InputTypes.KNOWN_INPUT: 2>), ('StatSymbol', <DataTypes.CATEGORICAL: 1>, <InputTypes.STATIC_INPUT: 3>)]
# # input_size = 12
# # output_size = 1
# # category_counts = [10, 5, 20]
# # input_obs_loc = [7]
# # static_input_loc = [11]
# # known_regular_inputs = [8]
# # known_categorical_inputs = [0, 1, 2]
# # model_folder = output/saved_models/ohlc/main
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 257, 12)]    0           []
#
#  tf_op_layer_TemporalFusionTran  [(None, 257, 3)]    0           ['input_1[0][0]']
#  sformer/strided_slice_1 (Tenso
#  rFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 257)]       0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_4 (Tenso                                  former/strided_slice_1[0][0]']
#  rFlowOpLayer)
#
#  sequential_2 (Sequential)      (None, 257, 40)      800         ['tf_op_layer_TemporalFusionTrans
#                                                                  former/strided_slice_4[0][0]']
#
#  tf_op_layer_TemporalFusionTran  [(None, 40)]        0           ['sequential_2[0][0]']
#  sformer/strided_slice_5 (Tenso
#  rFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 1, 40)]     0           ['tf_op_layer_TemporalFusionTrans
#  sformer/stack (TensorFlowOpLay                                  former/strided_slice_5[0][0]']
#  er)
#
#  flatten (Flatten)              (None, 40)           0           ['tf_op_layer_TemporalFusionTrans
#                                                                  former/stack[0][0]']
#
#  dense_10 (Dense)               (None, 40)           1640        ['flatten[0][0]']
#
#  tf_op_layer_TemporalFusionTran  [(None, 1, 40)]     0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_19 (Tens                                  former/stack[0][0]']
#  orFlowOpLayer)
#
#  activation (Activation)        (None, 40)           0           ['dense_10[0][0]']
#
#  dense_14 (Dense)               (None, 1, 40)        1640        ['tf_op_layer_TemporalFusionTrans
#                                                                  former/strided_slice_19[0][0]']
#
#  dense_11 (Dense)               (None, 40)           1640        ['activation[0][0]']
#
#  activation_2 (Activation)      (None, 1, 40)        0           ['dense_14[0][0]']
#
#  dropout (Dropout)              (None, 40)           0           ['dense_11[0][0]']
#
#  dense_15 (Dense)               (None, 1, 40)        1640        ['activation_2[0][0]']
#
#  dense_12 (Dense)               (None, 1)            41          ['dropout[0][0]']
#
#  dense_13 (Dense)               (None, 1)            41          ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 1, 40)        0           ['dense_15[0][0]']
#
#  dense_9 (Dense)                (None, 1)            41          ['flatten[0][0]']
#
#  multiply (Multiply)            (None, 1)            0           ['dense_12[0][0]',
#                                                                   'dense_13[0][0]']
#
#  dense_16 (Dense)               (None, 1, 40)        1640        ['dropout_1[0][0]']
#
#  dense_17 (Dense)               (None, 1, 40)        1640        ['dropout_1[0][0]']
#
#  add (Add)                      (None, 1)            0           ['dense_9[0][0]',
#                                                                   'multiply[0][0]']
#
#  multiply_1 (Multiply)          (None, 1, 40)        0           ['dense_16[0][0]',
#                                                                   'dense_17[0][0]']
#
#  layer_normalization (LayerNorm  (None, 1)           2           ['add[0][0]']
#  alization)
#
#  add_1 (Add)                    (None, 1, 40)        0           ['tf_op_layer_TemporalFusionTrans
#                                                                  former/strided_slice_19[0][0]',
#                                                                   'multiply_1[0][0]']
#
#  activation_1 (Activation)      (None, 1)            0           ['layer_normalization[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 1, 40)       80          ['add_1[0][0]']
#  rmalization)
#
#  tf_op_layer_TemporalFusionTran  [(None, 1, 1)]      0           ['activation_1[0][0]']
#  sformer/ExpandDims (TensorFlow
#  OpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 1, 40)]     0           ['layer_normalization_1[0][0]']
#  sformer/concat_1/concat (Tenso
#  rFlowOpLayer)
#
#  multiply_2 (Multiply)          (None, 1, 40)        0           ['tf_op_layer_TemporalFusionTrans
#                                                                  former/ExpandDims[0][0]',
#                                                                   'tf_op_layer_TemporalFusionTrans
#                                                                  former/concat_1/concat[0][0]']
#
#  tf_op_layer_TemporalFusionTran  [(None, 40)]        0           ['multiply_2[0][0]']
#  sformer/Sum (TensorFlowOpLayer
#  )
#
#  dense_18 (Dense)               (None, 40)           1640        ['tf_op_layer_TemporalFusionTrans
#                                                                  former/Sum[0][0]']
#
#  activation_3 (Activation)      (None, 40)           0           ['dense_18[0][0]']
#
#  tf_op_layer_TemporalFusionTran  [(None, 257, 9)]    0           ['input_1[0][0]']
#  sformer/strided_slice (TensorF
#  lowOpLayer)
#
#  dense_19 (Dense)               (None, 40)           1640        ['activation_3[0][0]']
#
#  tf_op_layer_TemporalFusionTran  [(None, 257, 1)]    0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_7 (Tenso                                  former/strided_slice[0][0]']
#  rFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 257, 1)]    0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_8 (Tenso                                  former/strided_slice[0][0]']
#  rFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 257, 1)]    0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_9 (Tenso                                  former/strided_slice[0][0]']
#  rFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 257, 1)]    0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_10 (Tens                                  former/strided_slice[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 257, 1)]    0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_11 (Tens                                  former/strided_slice[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 257, 1)]    0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_12 (Tens                                  former/strided_slice[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 257, 1)]    0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_13 (Tens                                  former/strided_slice[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 257, 1)]    0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_14 (Tens                                  former/strided_slice[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 257)]       0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_2 (Tenso                                  former/strided_slice_1[0][0]']
#  rFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 257)]       0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_3 (Tenso                                  former/strided_slice_1[0][0]']
#  rFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 257, 1)]    0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_6 (Tenso                                  former/strided_slice[0][0]']
#  rFlowOpLayer)
#
#  dropout_2 (Dropout)            (None, 40)           0           ['dense_19[0][0]']
#
#  time_distributed_1 (TimeDistri  (None, 257, 40)     80          ['tf_op_layer_TemporalFusionTrans
#  buted)                                                          former/strided_slice_7[0][0]']
#
#  time_distributed_2 (TimeDistri  (None, 257, 40)     80          ['tf_op_layer_TemporalFusionTrans
#  buted)                                                          former/strided_slice_8[0][0]']
#
#  time_distributed_3 (TimeDistri  (None, 257, 40)     80          ['tf_op_layer_TemporalFusionTrans
#  buted)                                                          former/strided_slice_9[0][0]']
#
#  time_distributed_4 (TimeDistri  (None, 257, 40)     80          ['tf_op_layer_TemporalFusionTrans
#  buted)                                                          former/strided_slice_10[0][0]']
#
#  time_distributed_5 (TimeDistri  (None, 257, 40)     80          ['tf_op_layer_TemporalFusionTrans
#  buted)                                                          former/strided_slice_11[0][0]']
#
#  time_distributed_6 (TimeDistri  (None, 257, 40)     80          ['tf_op_layer_TemporalFusionTrans
#  buted)                                                          former/strided_slice_12[0][0]']
#
#  time_distributed_7 (TimeDistri  (None, 257, 40)     80          ['tf_op_layer_TemporalFusionTrans
#  buted)                                                          former/strided_slice_13[0][0]']
#
#  time_distributed_8 (TimeDistri  (None, 257, 40)     80          ['tf_op_layer_TemporalFusionTrans
#  buted)                                                          former/strided_slice_14[0][0]']
#
#  sequential (Sequential)        (None, 257, 40)      400         ['tf_op_layer_TemporalFusionTrans
#                                                                  former/strided_slice_2[0][0]']
#
#  sequential_1 (Sequential)      (None, 257, 40)      200         ['tf_op_layer_TemporalFusionTrans
#                                                                  former/strided_slice_3[0][0]']
#
#  time_distributed (TimeDistribu  (None, 257, 40)     80          ['tf_op_layer_TemporalFusionTrans
#  ted)                                                            former/strided_slice_6[0][0]']
#
#  dense_20 (Dense)               (None, 40)           1640        ['dropout_2[0][0]']
#
#  dense_21 (Dense)               (None, 40)           1640        ['dropout_2[0][0]']
#
#  tf_op_layer_TemporalFusionTran  [(None, 257, 40, 7)  0          ['time_distributed_1[0][0]',
#  sformer/stack_2 (TensorFlowOpL  ]                                'time_distributed_2[0][0]',
#  ayer)                                                            'time_distributed_3[0][0]',
#                                                                   'time_distributed_4[0][0]',
#                                                                   'time_distributed_5[0][0]',
#                                                                   'time_distributed_6[0][0]',
#                                                                   'time_distributed_7[0][0]']
#
#  tf_op_layer_TemporalFusionTran  [(None, 257, 40, 3)  0          ['time_distributed_8[0][0]',
#  sformer/stack_3 (TensorFlowOpL  ]                                'sequential[0][0]',
#  ayer)                                                            'sequential_1[0][0]']
#
#  tf_op_layer_TemporalFusionTran  [(None, 257, 40, 1)  0          ['time_distributed[0][0]']
#  sformer/stack_1 (TensorFlowOpL  ]
#  ayer)
#
#  multiply_3 (Multiply)          (None, 40)           0           ['dense_20[0][0]',
#                                                                   'dense_21[0][0]']
#
#  tf_op_layer_TemporalFusionTran  [(None, 252, 40, 7)  0          ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_15 (Tens  ]                               former/stack_2[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 252, 40, 3)  0          ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_16 (Tens  ]                               former/stack_3[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 252, 40, 1)  0          ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_17 (Tens  ]                               former/stack_1[0][0]']
#  orFlowOpLayer)
#
#  add_2 (Add)                    (None, 40)           0           ['tf_op_layer_TemporalFusionTrans
#                                                                  former/Sum[0][0]',
#                                                                   'multiply_3[0][0]']
#
#  tf_op_layer_TemporalFusionTran  [(None, 252, 40, 11  0          ['tf_op_layer_TemporalFusionTrans
#  sformer/concat (TensorFlowOpLa  )]                              former/strided_slice_15[0][0]',
#  yer)                                                             'tf_op_layer_TemporalFusionTrans
#                                                                  former/strided_slice_16[0][0]',
#                                                                   'tf_op_layer_TemporalFusionTrans
#                                                                  former/strided_slice_17[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 40)          80          ['add_2[0][0]']
#  rmalization)
#
#  tf_op_layer_TemporalFusionTran  [(None, 252, 440)]  0           ['tf_op_layer_TemporalFusionTrans
#  sformer/Reshape (TensorFlowOpL                                  former/concat[0][0]']
#  ayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 1, 40)]     0           ['layer_normalization_2[0][0]']
#  sformer/ExpandDims_1 (TensorFl
#  owOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 5, 40, 3)]  0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_18 (Tens                                  former/stack_3[0][0]']
#  orFlowOpLayer)
#
#  time_distributed_10 (TimeDistr  (None, 252, 40)     17640       ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/Reshape[0][0]']
#
#  time_distributed_11 (TimeDistr  (None, 1, 40)       1600        ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/ExpandDims_1[0][0]']
#
#  tf_op_layer_TemporalFusionTran  [(None, 5, 120)]    0           ['tf_op_layer_TemporalFusionTrans
#  sformer/Reshape_1 (TensorFlowO                                  former/strided_slice_18[0][0]']
#  pLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 1, 40)]     0           ['layer_normalization_2[0][0]']
#  sformer/ExpandDims_3 (TensorFl
#  owOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 252, 40)]   0           ['time_distributed_10[0][0]',
#  sformer/add_6 (TensorFlowOpLay                                   'time_distributed_11[0][0]']
#  er)
#
#  tf_op_layer_TemporalFusionTran  [(None, 252, 40)]   0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_20 (Tens                                  former/concat[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 252, 40)]   0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_21 (Tens                                  former/concat[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 252, 40)]   0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_22 (Tens                                  former/concat[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 252, 40)]   0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_23 (Tens                                  former/concat[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 252, 40)]   0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_24 (Tens                                  former/concat[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 252, 40)]   0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_25 (Tens                                  former/concat[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 252, 40)]   0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_26 (Tens                                  former/concat[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 252, 40)]   0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_27 (Tens                                  former/concat[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 252, 40)]   0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_28 (Tens                                  former/concat[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 252, 40)]   0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_29 (Tens                                  former/concat[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 252, 40)]   0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_30 (Tens                                  former/concat[0][0]']
#  orFlowOpLayer)
#
#  time_distributed_60 (TimeDistr  (None, 5, 40)       4840        ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/Reshape_1[0][0]']
#
#  time_distributed_61 (TimeDistr  (None, 1, 40)       1600        ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/ExpandDims_3[0][0]']
#
#  activation_7 (Activation)      (None, 252, 40)      0           ['tf_op_layer_TemporalFusionTrans
#                                                                  former/add_6[0][0]']
#
#  time_distributed_15 (TimeDistr  (None, 252, 40)     1640        ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/strided_slice_20[0][0]']
#
#  time_distributed_19 (TimeDistr  (None, 252, 40)     1640        ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/strided_slice_21[0][0]']
#
#  time_distributed_23 (TimeDistr  (None, 252, 40)     1640        ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/strided_slice_22[0][0]']
#
#  time_distributed_27 (TimeDistr  (None, 252, 40)     1640        ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/strided_slice_23[0][0]']
#
#  time_distributed_31 (TimeDistr  (None, 252, 40)     1640        ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/strided_slice_24[0][0]']
#
#  time_distributed_35 (TimeDistr  (None, 252, 40)     1640        ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/strided_slice_25[0][0]']
#
#  time_distributed_39 (TimeDistr  (None, 252, 40)     1640        ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/strided_slice_26[0][0]']
#
#  time_distributed_43 (TimeDistr  (None, 252, 40)     1640        ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/strided_slice_27[0][0]']
#
#  time_distributed_47 (TimeDistr  (None, 252, 40)     1640        ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/strided_slice_28[0][0]']
#
#  time_distributed_51 (TimeDistr  (None, 252, 40)     1640        ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/strided_slice_29[0][0]']
#
#  time_distributed_55 (TimeDistr  (None, 252, 40)     1640        ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/strided_slice_30[0][0]']
#
#  tf_op_layer_TemporalFusionTran  [(None, 5, 40)]     0           ['time_distributed_60[0][0]',
#  sformer/add_18 (TensorFlowOpLa                                   'time_distributed_61[0][0]']
#  yer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 5, 40)]     0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_31 (Tens                                  former/strided_slice_18[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 5, 40)]     0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_32 (Tens                                  former/strided_slice_18[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 5, 40)]     0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_33 (Tens                                  former/strided_slice_18[0][0]']
#  orFlowOpLayer)
#
#  time_distributed_12 (TimeDistr  (None, 252, 40)     1640        ['activation_7[0][0]']
#  ibuted)
#
#  activation_9 (Activation)      (None, 252, 40)      0           ['time_distributed_15[0][0]']
#
#  activation_10 (Activation)     (None, 252, 40)      0           ['time_distributed_19[0][0]']
#
#  activation_11 (Activation)     (None, 252, 40)      0           ['time_distributed_23[0][0]']
#
#  activation_12 (Activation)     (None, 252, 40)      0           ['time_distributed_27[0][0]']
#
#  activation_13 (Activation)     (None, 252, 40)      0           ['time_distributed_31[0][0]']
#
#  activation_14 (Activation)     (None, 252, 40)      0           ['time_distributed_35[0][0]']
#
#  activation_15 (Activation)     (None, 252, 40)      0           ['time_distributed_39[0][0]']
#
#  activation_16 (Activation)     (None, 252, 40)      0           ['time_distributed_43[0][0]']
#
#  activation_17 (Activation)     (None, 252, 40)      0           ['time_distributed_47[0][0]']
#
#  activation_18 (Activation)     (None, 252, 40)      0           ['time_distributed_51[0][0]']
#
#  activation_19 (Activation)     (None, 252, 40)      0           ['time_distributed_55[0][0]']
#
#  activation_20 (Activation)     (None, 5, 40)        0           ['tf_op_layer_TemporalFusionTrans
#                                                                  former/add_18[0][0]']
#
#  time_distributed_65 (TimeDistr  (None, 5, 40)       1640        ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/strided_slice_31[0][0]']
#
#  time_distributed_69 (TimeDistr  (None, 5, 40)       1640        ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/strided_slice_32[0][0]']
#
#  time_distributed_73 (TimeDistr  (None, 5, 40)       1640        ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/strided_slice_33[0][0]']
#
#  dropout_6 (Dropout)            (None, 252, 40)      0           ['time_distributed_12[0][0]']
#
#  time_distributed_16 (TimeDistr  (None, 252, 40)     1640        ['activation_9[0][0]']
#  ibuted)
#
#  time_distributed_20 (TimeDistr  (None, 252, 40)     1640        ['activation_10[0][0]']
#  ibuted)
#
#  time_distributed_24 (TimeDistr  (None, 252, 40)     1640        ['activation_11[0][0]']
#  ibuted)
#
#  time_distributed_28 (TimeDistr  (None, 252, 40)     1640        ['activation_12[0][0]']
#  ibuted)
#
#  time_distributed_32 (TimeDistr  (None, 252, 40)     1640        ['activation_13[0][0]']
#  ibuted)
#
#  time_distributed_36 (TimeDistr  (None, 252, 40)     1640        ['activation_14[0][0]']
#  ibuted)
#
#  time_distributed_40 (TimeDistr  (None, 252, 40)     1640        ['activation_15[0][0]']
#  ibuted)
#
#  time_distributed_44 (TimeDistr  (None, 252, 40)     1640        ['activation_16[0][0]']
#  ibuted)
#
#  time_distributed_48 (TimeDistr  (None, 252, 40)     1640        ['activation_17[0][0]']
#  ibuted)
#
#  time_distributed_52 (TimeDistr  (None, 252, 40)     1640        ['activation_18[0][0]']
#  ibuted)
#
#  time_distributed_56 (TimeDistr  (None, 252, 40)     1640        ['activation_19[0][0]']
#  ibuted)
#
#  time_distributed_62 (TimeDistr  (None, 5, 40)       1640        ['activation_20[0][0]']
#  ibuted)
#
#  activation_22 (Activation)     (None, 5, 40)        0           ['time_distributed_65[0][0]']
#
#  activation_23 (Activation)     (None, 5, 40)        0           ['time_distributed_69[0][0]']
#
#  activation_24 (Activation)     (None, 5, 40)        0           ['time_distributed_73[0][0]']
#
#  time_distributed_13 (TimeDistr  (None, 252, 11)     451         ['dropout_6[0][0]']
#  ibuted)
#
# ...
#                                                                   'multiply_26[0][0]']
#
#  layer_normalization_23 (LayerN  (None, 257, 240)    480         ['add_23[0][0]']
#  ormalization)
#
#  tf_op_layer_TemporalFusionTran  [(3,)]              0           ['layer_normalization_23[0][0]']
#  sformer/Shape (TensorFlowOpLay
#  er)
#
#  tf_op_layer_TemporalFusionTran  [()]                0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_34 (Tens                                  former/Shape[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(3,)]              0           ['layer_normalization_23[0][0]']
#  sformer/Shape_1 (TensorFlowOpL
#  ayer)
#
#  tf_op_layer_TemporalFusionTran  [()]                0           ['tf_op_layer_TemporalFusionTrans
#  sformer/eye/Minimum (TensorFlo                                  former/strided_slice_34[0][0]',
#  wOpLayer)                                                        'tf_op_layer_TemporalFusionTrans
#                                                                  former/strided_slice_34[0][0]']
#
#  tf_op_layer_TemporalFusionTran  [(1,)]              0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_35 (Tens                                  former/Shape_1[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(1,)]              0           ['tf_op_layer_TemporalFusionTrans
#  sformer/eye/concat/values_1 (T                                  former/eye/Minimum[0][0]']
#  ensorFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(2,)]              0           ['tf_op_layer_TemporalFusionTrans
#  sformer/eye/concat (TensorFlow                                  former/strided_slice_35[0][0]',
#  OpLayer)                                                         'tf_op_layer_TemporalFusionTrans
#                                                                  former/eye/concat/values_1[0][0]'
#                                                                  ]
#
#  tf_op_layer_TemporalFusionTran  [(None, None)]      0           ['tf_op_layer_TemporalFusionTrans
#  sformer/eye/ones (TensorFlowOp                                  former/eye/concat[0][0]']
#  Layer)
#
#  tf_op_layer_TemporalFusionTran  [(None, None, None)  0          ['tf_op_layer_TemporalFusionTrans
#  sformer/eye/diag (TensorFlowOp  ]                               former/eye/ones[0][0]']
#  Layer)
#
#  dense_110 (Dense)              (None, 257, 240)     57600       ['layer_normalization_23[0][0]']
#
#  dense_111 (Dense)              (None, 257, 240)     57600       ['layer_normalization_23[0][0]']
#
#  tf_op_layer_TemporalFusionTran  [(None, None, None)  0          ['tf_op_layer_TemporalFusionTrans
#  sformer/Cumsum (TensorFlowOpLa  ]                               former/eye/diag[0][0]']
#  yer)
#
#  lambda (Lambda)                (None, 257, 257)     0           ['dense_110[0][0]',
#                                                                   'dense_111[0][0]']
#
#  lambda_1 (Lambda)              (None, None, None)   0           ['tf_op_layer_TemporalFusionTrans
#                                                                  former/Cumsum[0][0]']
#
#  add_24 (Add)                   (None, 257, 257)     0           ['lambda[0][0]',
#                                                                   'lambda_1[0][0]']
#
#  activation_26 (Activation)     (None, 257, 257)     0           ['add_24[0][0]']
#
#  dropout_24 (Dropout)           (None, 257, 257)     0           ['activation_26[0][0]']
#
#  dense_109 (Dense)              (None, 257, 240)     57600       ['layer_normalization_23[0][0]']
#
#  lambda_2 (Lambda)              (None, 257, 240)     0           ['dropout_24[0][0]',
#                                                                   'dense_109[0][0]']
#
#  dropout_25 (Dropout)           (None, 257, 240)     0           ['lambda_2[0][0]']
#
#  dense_112 (Dense)              (None, 257, 240)     57600       ['dropout_25[0][0]']
#
#  dropout_26 (Dropout)           (None, 257, 240)     0           ['dense_112[0][0]']
#
#  dropout_27 (Dropout)           (None, 257, 240)     0           ['dropout_26[0][0]']
#
#  time_distributed_84 (TimeDistr  (None, 257, 240)    57840       ['dropout_27[0][0]']
#  ibuted)
#
#  time_distributed_85 (TimeDistr  (None, 257, 240)    57840       ['dropout_27[0][0]']
#  ibuted)
#
#  multiply_27 (Multiply)         (None, 257, 240)     0           ['time_distributed_84[0][0]',
#                                                                   'time_distributed_85[0][0]']
#
#  add_25 (Add)                   (None, 257, 240)     0           ['multiply_27[0][0]',
#                                                                   'layer_normalization_23[0][0]']
#
#  layer_normalization_24 (LayerN  (None, 257, 240)    480         ['add_25[0][0]']
#  ormalization)
#
#  time_distributed_86 (TimeDistr  (None, 257, 240)    57840       ['layer_normalization_24[0][0]']
#  ibuted)
#
#  activation_27 (Activation)     (None, 257, 240)     0           ['time_distributed_86[0][0]']
#
#  time_distributed_87 (TimeDistr  (None, 257, 240)    57840       ['activation_27[0][0]']
#  ibuted)
#
#  dropout_28 (Dropout)           (None, 257, 240)     0           ['time_distributed_87[0][0]']
#
#  time_distributed_88 (TimeDistr  (None, 257, 240)    57840       ['dropout_28[0][0]']
#  ibuted)
#
#  time_distributed_89 (TimeDistr  (None, 257, 240)    57840       ['dropout_28[0][0]']
#  ibuted)
#
#  multiply_28 (Multiply)         (None, 257, 240)     0           ['time_distributed_88[0][0]',
#                                                                   'time_distributed_89[0][0]']
#
#  add_26 (Add)                   (None, 257, 240)     0           ['layer_normalization_24[0][0]',
#                                                                   'multiply_28[0][0]']
#
#  layer_normalization_25 (LayerN  (None, 257, 240)    480         ['add_26[0][0]']
#  ormalization)
#
#  time_distributed_90 (TimeDistr  (None, 257, 240)    57840       ['layer_normalization_25[0][0]']
#  ibuted)
#
#  time_distributed_91 (TimeDistr  (None, 257, 240)    57840       ['layer_normalization_25[0][0]']
#  ibuted)
#
#  multiply_29 (Multiply)         (None, 257, 240)     0           ['time_distributed_90[0][0]',
#                                                                   'time_distributed_91[0][0]']
#
#  add_27 (Add)                   (None, 257, 240)     0           ['multiply_29[0][0]',
#                                                                   'layer_normalization_22[0][0]']
#
#  layer_normalization_26 (LayerN  (None, 257, 240)    480         ['add_27[0][0]']
#  ormalization)
#
#  tf_op_layer_TemporalFusionTran  [(None, 5, 240)]    0           ['layer_normalization_26[0][0]']
#  sformer/strided_slice_40 (Tens
#  orFlowOpLayer)
#
#  time_distributed_92 (TimeDistr  (None, 5, 3)        723         ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/strided_slice_40[0][0]']
#
# ==================================================================================================
# Total params: 7,636,158
# Trainable params: 7,636,158
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# *** Fitting TemporalFusionTransformer ***
# Getting batched_data
# Using cached training data
# Using cached validation data
# Using keras standard fit
# Train on 41680 samples, validate on 19000 samples
# Epoch 1/100
# 34560/41680 [=======================>......] - ETA: 46s - loss: 0.2266Traceback (most recent call last):
#   File "/kaggle/working/pythonProject/script_hyperparam_opt.py", line 226, in <module>
#     main(
#   File "/kaggle/working/pythonProject/script_hyperparam_opt.py", line 110, in main
#     model.fit()
#   File "/kaggle/working/pythonProject/libs/tft_model.py", line 1156, in fit
#     self.model.fit(
#   File "/opt/conda/lib/python3.10/site-packages/keras/engine/training_v1.py", line 856, in fit
#     return func.fit(
#   File "/opt/conda/lib/python3.10/site-packages/keras/engine/training_arrays_v1.py", line 734, in fit
#     return fit_loop(
#   File "/opt/conda/lib/python3.10/site-packages/keras/engine/training_arrays_v1.py", line 421, in model_iteration
#     batch_outs = f(ins_batch)
#   File "/opt/conda/lib/python3.10/site-packages/keras/backend.py", line 4608, in __call__
#     fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#   File "/opt/conda/lib/python3.10/site-packages/tensorflow/python/client/session.py", line 1481, in __call__
#     ret = tf_session.TF_SessionRunCallable(self._session._session,
# tensorflow.python.framework.errors_impl.ResourceExhaustedError: OOM when allocating tensor with shape[256,252,240,11] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node training/Adam/gradients/gradients/TemporalFusionTransformer/strided_slice_28_grad/StridedSliceGrad}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.

# %%
# %ls -a
# Out:
# ./         data_formatters/    output_mas.pickle   run.sh*
# ../        expt_settings/      post_processing.py  scaler.pickle
# .git/      libs/               preprocessing/      script_download_data.py
# README.md  output/             report.txt          script_hyperparam_opt.py
# cache/     output_mape.pickle  requirements.txt    script_train_fixed_params.py
