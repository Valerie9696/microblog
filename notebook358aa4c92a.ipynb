# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !git clone https://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@github.com/Valerie9696/pythonProject
# Out:
# fatal: destination path 'pythonProject' already exists and is not an empty directory.

# %%
# %cd pythonProject/
# Out:
# /kaggle/working/pythonProject

# %%
# !python script_hyperparam_opt.py ohlc output yes

# %%
# !python script_train_fixed_params.py ohlc output yes
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Using output folder output
# cache/model_folder
# Selecting GPU ID=0
# *** Training from defined parameters for ohlc ***
# Loading & splitting data...
# Formatting train-valid-test splits.
# Setting scalers with training data...
# *** Loading hyperparm manager ***
# *** Running calibration ***
# Params Selected:
# dropout_rate: 0.1
# hidden_layer_size: 10
# learning_rate: 0.01
# minibatch_size: 64
# max_gradient_norm: 1.0
# num_heads: 1
# stack_size: 1
# model_folder: output/saved_models/ohlc/fixed
# Resetting temp folder...
# *** TemporalFusionTransformer params ***
# # dropout_rate = 0.1
# # hidden_layer_size = 10
# # learning_rate = 0.01
# # max_gradient_norm = 1.0
# # minibatch_size = 64
# # model_folder = output/saved_models/ohlc/fixed
# # num_heads = 1
# # stack_size = 1
# # total_time_steps = 257
# # num_encoder_steps = 252
# # num_epochs = 100
# # early_stopping_patience = 5
# # multiprocessing_workers = 5
# # column_definition = [('Symbol', <DataTypes.CATEGORICAL: 1>, <InputTypes.ID: 4>), ('Datetime', <DataTypes.DATE: 2>, <InputTypes.TIME: 5>), ('Open', <DataTypes.REAL_VALUED: 0>, <InputTypes.OBSERVED_INPUT: 1>), ('High', <DataTypes.REAL_VALUED: 0>, <InputTypes.OBSERVED_INPUT: 1>), ('Low', <DataTypes.REAL_VALUED: 0>, <InputTypes.OBSERVED_INPUT: 1>), ('HighLowDifference', <DataTypes.REAL_VALUED: 0>, <InputTypes.OBSERVED_INPUT: 1>), ('OpenCloseDifference', <DataTypes.REAL_VALUED: 0>, <InputTypes.OBSERVED_INPUT: 1>), ('ATR', <DataTypes.REAL_VALUED: 0>, <InputTypes.OBSERVED_INPUT: 1>), ('RSI', <DataTypes.REAL_VALUED: 0>, <InputTypes.OBSERVED_INPUT: 1>), ('Close', <DataTypes.REAL_VALUED: 0>, <InputTypes.TARGET: 0>), ('HoursFromStart', <DataTypes.REAL_VALUED: 0>, <InputTypes.KNOWN_INPUT: 2>), ('HourOfDay', <DataTypes.CATEGORICAL: 1>, <InputTypes.KNOWN_INPUT: 2>), ('DayOfWeek', <DataTypes.CATEGORICAL: 1>, <InputTypes.KNOWN_INPUT: 2>), ('StatSymbol', <DataTypes.CATEGORICAL: 1>, <InputTypes.STATIC_INPUT: 3>)]
# # input_size = 12
# # output_size = 1
# # category_counts = [10, 5, 20]
# # input_obs_loc = [7]
# # static_input_loc = [11]
# # known_regular_inputs = [8]
# # known_categorical_inputs = [0, 1, 2]
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 257, 12)]    0           []
#
#  tf_op_layer_TemporalFusionTran  [(None, 257, 3)]    0           ['input_1[0][0]']
#  sformer/strided_slice_1 (Tenso
#  rFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 257)]       0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_4 (Tenso                                  former/strided_slice_1[0][0]']
#  rFlowOpLayer)
#
#  sequential_2 (Sequential)      (None, 257, 10)      200         ['tf_op_layer_TemporalFusionTrans
#                                                                  former/strided_slice_4[0][0]']
#
#  tf_op_layer_TemporalFusionTran  [(None, 10)]        0           ['sequential_2[0][0]']
#  sformer/strided_slice_5 (Tenso
#  rFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 1, 10)]     0           ['tf_op_layer_TemporalFusionTrans
#  sformer/stack (TensorFlowOpLay                                  former/strided_slice_5[0][0]']
#  er)
#
#  flatten (Flatten)              (None, 10)           0           ['tf_op_layer_TemporalFusionTrans
#                                                                  former/stack[0][0]']
#
#  dense_10 (Dense)               (None, 10)           110         ['flatten[0][0]']
#
#  tf_op_layer_TemporalFusionTran  [(None, 1, 10)]     0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_19 (Tens                                  former/stack[0][0]']
#  orFlowOpLayer)
#
#  activation (Activation)        (None, 10)           0           ['dense_10[0][0]']
#
#  dense_14 (Dense)               (None, 1, 10)        110         ['tf_op_layer_TemporalFusionTrans
#                                                                  former/strided_slice_19[0][0]']
#
#  dense_11 (Dense)               (None, 10)           110         ['activation[0][0]']
#
#  activation_2 (Activation)      (None, 1, 10)        0           ['dense_14[0][0]']
#
#  dropout (Dropout)              (None, 10)           0           ['dense_11[0][0]']
#
#  dense_15 (Dense)               (None, 1, 10)        110         ['activation_2[0][0]']
#
#  dense_12 (Dense)               (None, 1)            11          ['dropout[0][0]']
#
#  dense_13 (Dense)               (None, 1)            11          ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 1, 10)        0           ['dense_15[0][0]']
#
#  dense_9 (Dense)                (None, 1)            11          ['flatten[0][0]']
#
#  multiply (Multiply)            (None, 1)            0           ['dense_12[0][0]',
#                                                                   'dense_13[0][0]']
#
#  dense_16 (Dense)               (None, 1, 10)        110         ['dropout_1[0][0]']
#
#  dense_17 (Dense)               (None, 1, 10)        110         ['dropout_1[0][0]']
#
#  add (Add)                      (None, 1)            0           ['dense_9[0][0]',
#                                                                   'multiply[0][0]']
#
#  multiply_1 (Multiply)          (None, 1, 10)        0           ['dense_16[0][0]',
#                                                                   'dense_17[0][0]']
#
#  layer_normalization (LayerNorm  (None, 1)           2           ['add[0][0]']
#  alization)
#
#  add_1 (Add)                    (None, 1, 10)        0           ['tf_op_layer_TemporalFusionTrans
#                                                                  former/strided_slice_19[0][0]',
#                                                                   'multiply_1[0][0]']
#
#  activation_1 (Activation)      (None, 1)            0           ['layer_normalization[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 1, 10)       20          ['add_1[0][0]']
#  rmalization)
#
#  tf_op_layer_TemporalFusionTran  [(None, 1, 1)]      0           ['activation_1[0][0]']
#  sformer/ExpandDims (TensorFlow
#  OpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 1, 10)]     0           ['layer_normalization_1[0][0]']
#  sformer/concat_1/concat (Tenso
#  rFlowOpLayer)
#
#  multiply_2 (Multiply)          (None, 1, 10)        0           ['tf_op_layer_TemporalFusionTrans
#                                                                  former/ExpandDims[0][0]',
#                                                                   'tf_op_layer_TemporalFusionTrans
#                                                                  former/concat_1/concat[0][0]']
#
#  tf_op_layer_TemporalFusionTran  [(None, 10)]        0           ['multiply_2[0][0]']
#  sformer/Sum (TensorFlowOpLayer
#  )
#
#  dense_18 (Dense)               (None, 10)           110         ['tf_op_layer_TemporalFusionTrans
#                                                                  former/Sum[0][0]']
#
#  activation_3 (Activation)      (None, 10)           0           ['dense_18[0][0]']
#
#  tf_op_layer_TemporalFusionTran  [(None, 257, 9)]    0           ['input_1[0][0]']
#  sformer/strided_slice (TensorF
#  lowOpLayer)
#
#  dense_19 (Dense)               (None, 10)           110         ['activation_3[0][0]']
#
#  tf_op_layer_TemporalFusionTran  [(None, 257, 1)]    0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_7 (Tenso                                  former/strided_slice[0][0]']
#  rFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 257, 1)]    0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_8 (Tenso                                  former/strided_slice[0][0]']
#  rFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 257, 1)]    0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_9 (Tenso                                  former/strided_slice[0][0]']
#  rFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 257, 1)]    0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_10 (Tens                                  former/strided_slice[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 257, 1)]    0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_11 (Tens                                  former/strided_slice[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 257, 1)]    0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_12 (Tens                                  former/strided_slice[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 257, 1)]    0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_13 (Tens                                  former/strided_slice[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 257, 1)]    0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_14 (Tens                                  former/strided_slice[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 257)]       0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_2 (Tenso                                  former/strided_slice_1[0][0]']
#  rFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 257)]       0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_3 (Tenso                                  former/strided_slice_1[0][0]']
#  rFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 257, 1)]    0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_6 (Tenso                                  former/strided_slice[0][0]']
#  rFlowOpLayer)
#
#  dropout_2 (Dropout)            (None, 10)           0           ['dense_19[0][0]']
#
#  time_distributed_1 (TimeDistri  (None, 257, 10)     20          ['tf_op_layer_TemporalFusionTrans
#  buted)                                                          former/strided_slice_7[0][0]']
#
#  time_distributed_2 (TimeDistri  (None, 257, 10)     20          ['tf_op_layer_TemporalFusionTrans
#  buted)                                                          former/strided_slice_8[0][0]']
#
#  time_distributed_3 (TimeDistri  (None, 257, 10)     20          ['tf_op_layer_TemporalFusionTrans
#  buted)                                                          former/strided_slice_9[0][0]']
#
#  time_distributed_4 (TimeDistri  (None, 257, 10)     20          ['tf_op_layer_TemporalFusionTrans
#  buted)                                                          former/strided_slice_10[0][0]']
#
#  time_distributed_5 (TimeDistri  (None, 257, 10)     20          ['tf_op_layer_TemporalFusionTrans
#  buted)                                                          former/strided_slice_11[0][0]']
#
#  time_distributed_6 (TimeDistri  (None, 257, 10)     20          ['tf_op_layer_TemporalFusionTrans
#  buted)                                                          former/strided_slice_12[0][0]']
#
#  time_distributed_7 (TimeDistri  (None, 257, 10)     20          ['tf_op_layer_TemporalFusionTrans
#  buted)                                                          former/strided_slice_13[0][0]']
#
#  time_distributed_8 (TimeDistri  (None, 257, 10)     20          ['tf_op_layer_TemporalFusionTrans
#  buted)                                                          former/strided_slice_14[0][0]']
#
#  sequential (Sequential)        (None, 257, 10)      100         ['tf_op_layer_TemporalFusionTrans
#                                                                  former/strided_slice_2[0][0]']
#
#  sequential_1 (Sequential)      (None, 257, 10)      50          ['tf_op_layer_TemporalFusionTrans
#                                                                  former/strided_slice_3[0][0]']
#
#  time_distributed (TimeDistribu  (None, 257, 10)     20          ['tf_op_layer_TemporalFusionTrans
#  ted)                                                            former/strided_slice_6[0][0]']
#
#  dense_20 (Dense)               (None, 10)           110         ['dropout_2[0][0]']
#
#  dense_21 (Dense)               (None, 10)           110         ['dropout_2[0][0]']
#
#  tf_op_layer_TemporalFusionTran  [(None, 257, 10, 7)  0          ['time_distributed_1[0][0]',
#  sformer/stack_2 (TensorFlowOpL  ]                                'time_distributed_2[0][0]',
#  ayer)                                                            'time_distributed_3[0][0]',
#                                                                   'time_distributed_4[0][0]',
#                                                                   'time_distributed_5[0][0]',
#                                                                   'time_distributed_6[0][0]',
#                                                                   'time_distributed_7[0][0]']
#
#  tf_op_layer_TemporalFusionTran  [(None, 257, 10, 3)  0          ['time_distributed_8[0][0]',
#  sformer/stack_3 (TensorFlowOpL  ]                                'sequential[0][0]',
#  ayer)                                                            'sequential_1[0][0]']
#
#  tf_op_layer_TemporalFusionTran  [(None, 257, 10, 1)  0          ['time_distributed[0][0]']
#  sformer/stack_1 (TensorFlowOpL  ]
#  ayer)
#
#  multiply_3 (Multiply)          (None, 10)           0           ['dense_20[0][0]',
#                                                                   'dense_21[0][0]']
#
#  tf_op_layer_TemporalFusionTran  [(None, 252, 10, 7)  0          ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_15 (Tens  ]                               former/stack_2[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 252, 10, 3)  0          ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_16 (Tens  ]                               former/stack_3[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 252, 10, 1)  0          ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_17 (Tens  ]                               former/stack_1[0][0]']
#  orFlowOpLayer)
#
#  add_2 (Add)                    (None, 10)           0           ['tf_op_layer_TemporalFusionTrans
#                                                                  former/Sum[0][0]',
#                                                                   'multiply_3[0][0]']
#
#  tf_op_layer_TemporalFusionTran  [(None, 252, 10, 11  0          ['tf_op_layer_TemporalFusionTrans
#  sformer/concat (TensorFlowOpLa  )]                              former/strided_slice_15[0][0]',
#  yer)                                                             'tf_op_layer_TemporalFusionTrans
#                                                                  former/strided_slice_16[0][0]',
#                                                                   'tf_op_layer_TemporalFusionTrans
#                                                                  former/strided_slice_17[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 10)          20          ['add_2[0][0]']
#  rmalization)
#
#  tf_op_layer_TemporalFusionTran  [(None, 252, 110)]  0           ['tf_op_layer_TemporalFusionTrans
#  sformer/Reshape (TensorFlowOpL                                  former/concat[0][0]']
#  ayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 1, 10)]     0           ['layer_normalization_2[0][0]']
#  sformer/ExpandDims_1 (TensorFl
#  owOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 5, 10, 3)]  0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_18 (Tens                                  former/stack_3[0][0]']
#  orFlowOpLayer)
#
#  time_distributed_10 (TimeDistr  (None, 252, 10)     1110        ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/Reshape[0][0]']
#
#  time_distributed_11 (TimeDistr  (None, 1, 10)       100         ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/ExpandDims_1[0][0]']
#
#  tf_op_layer_TemporalFusionTran  [(None, 5, 30)]     0           ['tf_op_layer_TemporalFusionTrans
#  sformer/Reshape_1 (TensorFlowO                                  former/strided_slice_18[0][0]']
#  pLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 1, 10)]     0           ['layer_normalization_2[0][0]']
#  sformer/ExpandDims_3 (TensorFl
#  owOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 252, 10)]   0           ['time_distributed_10[0][0]',
#  sformer/add_6 (TensorFlowOpLay                                   'time_distributed_11[0][0]']
#  er)
#
#  tf_op_layer_TemporalFusionTran  [(None, 252, 10)]   0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_20 (Tens                                  former/concat[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 252, 10)]   0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_21 (Tens                                  former/concat[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 252, 10)]   0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_22 (Tens                                  former/concat[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 252, 10)]   0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_23 (Tens                                  former/concat[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 252, 10)]   0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_24 (Tens                                  former/concat[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 252, 10)]   0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_25 (Tens                                  former/concat[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 252, 10)]   0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_26 (Tens                                  former/concat[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 252, 10)]   0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_27 (Tens                                  former/concat[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 252, 10)]   0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_28 (Tens                                  former/concat[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 252, 10)]   0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_29 (Tens                                  former/concat[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 252, 10)]   0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_30 (Tens                                  former/concat[0][0]']
#  orFlowOpLayer)
#
#  time_distributed_60 (TimeDistr  (None, 5, 10)       310         ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/Reshape_1[0][0]']
#
#  time_distributed_61 (TimeDistr  (None, 1, 10)       100         ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/ExpandDims_3[0][0]']
#
#  activation_7 (Activation)      (None, 252, 10)      0           ['tf_op_layer_TemporalFusionTrans
#                                                                  former/add_6[0][0]']
#
#  time_distributed_15 (TimeDistr  (None, 252, 10)     110         ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/strided_slice_20[0][0]']
#
#  time_distributed_19 (TimeDistr  (None, 252, 10)     110         ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/strided_slice_21[0][0]']
#
#  time_distributed_23 (TimeDistr  (None, 252, 10)     110         ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/strided_slice_22[0][0]']
#
#  time_distributed_27 (TimeDistr  (None, 252, 10)     110         ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/strided_slice_23[0][0]']
#
#  time_distributed_31 (TimeDistr  (None, 252, 10)     110         ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/strided_slice_24[0][0]']
#
#  time_distributed_35 (TimeDistr  (None, 252, 10)     110         ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/strided_slice_25[0][0]']
#
#  time_distributed_39 (TimeDistr  (None, 252, 10)     110         ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/strided_slice_26[0][0]']
#
#  time_distributed_43 (TimeDistr  (None, 252, 10)     110         ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/strided_slice_27[0][0]']
#
#  time_distributed_47 (TimeDistr  (None, 252, 10)     110         ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/strided_slice_28[0][0]']
#
#  time_distributed_51 (TimeDistr  (None, 252, 10)     110         ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/strided_slice_29[0][0]']
#
#  time_distributed_55 (TimeDistr  (None, 252, 10)     110         ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/strided_slice_30[0][0]']
#
#  tf_op_layer_TemporalFusionTran  [(None, 5, 10)]     0           ['time_distributed_60[0][0]',
#  sformer/add_18 (TensorFlowOpLa                                   'time_distributed_61[0][0]']
#  yer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 5, 10)]     0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_31 (Tens                                  former/strided_slice_18[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 5, 10)]     0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_32 (Tens                                  former/strided_slice_18[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 5, 10)]     0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_33 (Tens                                  former/strided_slice_18[0][0]']
#  orFlowOpLayer)
#
#  time_distributed_12 (TimeDistr  (None, 252, 10)     110         ['activation_7[0][0]']
#  ibuted)
#
#  activation_9 (Activation)      (None, 252, 10)      0           ['time_distributed_15[0][0]']
#
#  activation_10 (Activation)     (None, 252, 10)      0           ['time_distributed_19[0][0]']
#
#  activation_11 (Activation)     (None, 252, 10)      0           ['time_distributed_23[0][0]']
#
#  activation_12 (Activation)     (None, 252, 10)      0           ['time_distributed_27[0][0]']
#
#  activation_13 (Activation)     (None, 252, 10)      0           ['time_distributed_31[0][0]']
#
#  activation_14 (Activation)     (None, 252, 10)      0           ['time_distributed_35[0][0]']
#
#  activation_15 (Activation)     (None, 252, 10)      0           ['time_distributed_39[0][0]']
#
#  activation_16 (Activation)     (None, 252, 10)      0           ['time_distributed_43[0][0]']
#
#  activation_17 (Activation)     (None, 252, 10)      0           ['time_distributed_47[0][0]']
#
#  activation_18 (Activation)     (None, 252, 10)      0           ['time_distributed_51[0][0]']
#
#  activation_19 (Activation)     (None, 252, 10)      0           ['time_distributed_55[0][0]']
#
#  activation_20 (Activation)     (None, 5, 10)        0           ['tf_op_layer_TemporalFusionTrans
#                                                                  former/add_18[0][0]']
#
#  time_distributed_65 (TimeDistr  (None, 5, 10)       110         ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/strided_slice_31[0][0]']
#
#  time_distributed_69 (TimeDistr  (None, 5, 10)       110         ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/strided_slice_32[0][0]']
#
#  time_distributed_73 (TimeDistr  (None, 5, 10)       110         ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/strided_slice_33[0][0]']
#
#  dropout_6 (Dropout)            (None, 252, 10)      0           ['time_distributed_12[0][0]']
#
#  time_distributed_16 (TimeDistr  (None, 252, 10)     110         ['activation_9[0][0]']
#  ibuted)
#
#  time_distributed_20 (TimeDistr  (None, 252, 10)     110         ['activation_10[0][0]']
#  ibuted)
#
#  time_distributed_24 (TimeDistr  (None, 252, 10)     110         ['activation_11[0][0]']
#  ibuted)
#
#  time_distributed_28 (TimeDistr  (None, 252, 10)     110         ['activation_12[0][0]']
#  ibuted)
#
#  time_distributed_32 (TimeDistr  (None, 252, 10)     110         ['activation_13[0][0]']
#  ibuted)
#
#  time_distributed_36 (TimeDistr  (None, 252, 10)     110         ['activation_14[0][0]']
#  ibuted)
#
#  time_distributed_40 (TimeDistr  (None, 252, 10)     110         ['activation_15[0][0]']
#  ibuted)
#
#  time_distributed_44 (TimeDistr  (None, 252, 10)     110         ['activation_16[0][0]']
#  ibuted)
#
#  time_distributed_48 (TimeDistr  (None, 252, 10)     110         ['activation_17[0][0]']
#  ibuted)
#
#  time_distributed_52 (TimeDistr  (None, 252, 10)     110         ['activation_18[0][0]']
#  ibuted)
#
#  time_distributed_56 (TimeDistr  (None, 252, 10)     110         ['activation_19[0][0]']
#  ibuted)
#
#  time_distributed_62 (TimeDistr  (None, 5, 10)       110         ['activation_20[0][0]']
#  ibuted)
#
#  activation_22 (Activation)     (None, 5, 10)        0           ['time_distributed_65[0][0]']
#
#  activation_23 (Activation)     (None, 5, 10)        0           ['time_distributed_69[0][0]']
#
#  activation_24 (Activation)     (None, 5, 10)        0           ['time_distributed_73[0][0]']
#
#  time_distributed_13 (TimeDistr  (None, 252, 11)     121         ['dropout_6[0][0]']
#  ibuted)
# ...
#    4.3894020e-01  1.3738166e-01]
#  [ 2.7969676e-01  2.0691599e-01 -3.1751299e-01  3.6094919e-01
#    3.3293031e-02 -9.0706766e-02 -1.2443557e-02 -1.4189821e-01
#   -4.5915417e-02 -2.6088271e-01]]
# tensor: TemporalFusionTransformer/time_distributed_88/bias (float32) [10]
# [ 0.2309411  -0.04990922  0.01190189  0.08760334 -0.23928106  0.41689172
#  -0.05680458 -0.30476552  0.41181087 -0.34569806]
# tensor: TemporalFusionTransformer/time_distributed_88/kernel (float32) [10, 10]
# [[ 0.28118733  0.6079027  -0.15513127 -0.13372351 -0.11284044 -0.48098576
#   -0.5924553  -0.23431404  0.21783437 -0.3975588 ]
#  [ 0.35750356  0.65033364  0.27167657 -0.24116471  0.08326154 -0.25026813
#   -0.08535815 -0.29442903  0.10754782 -0.19226192]
#  [-0.23733778  0.02246721 -0.00387209  0.21172103 -0.22307198  0.46951386
#   -0.25885147  0.50385195  0.2755142   0.11930621]
#  [ 0.14842169 -0.10504759 -0.2174167   0.19623242 -0.09154609 -0.21534334
#   -0.33020684  0.316581   -0.18551743 -0.65359616]
#  [ 0.10599343 -0.15139604 -0.11870223 -0.02569205 -0.01487761 -0.05598078
#    0.14913474  0.08668589  0.10508735  0.05010689]
#  [ 0.01749816  0.02992088  0.15812705 -0.2112775  -0.16557254  0.06294943
#    0.01660995  0.1578853  -0.00960369 -0.03759378]
#  [-0.08579648 -0.4543437  -0.15135318  0.37405077  0.22333655  0.06235413
#    0.17811276 -0.03585283  0.02478642  0.08939265]
#  [-0.18955366  0.4323641  -0.27175784 -0.06166542 -0.13254337 -1.0727692
#    0.09022371 -0.02089875 -0.10954049 -1.3144965 ]
#  [-0.6611937  -1.4340736  -0.07643286 -1.3126286   0.55953634 -0.18114716
#   -0.9928829  -1.8885378  -0.18706095  0.20204647]
#  [ 0.04083698  0.01522284 -0.7189898   0.17351018  0.71598095  0.05376873
#   -0.32248688  0.62569654  0.12295353  0.15165594]
#  [ 0.83564174 -0.23986727 -0.3426672   0.74260473  0.04585028  0.0657698
#    0.0627505   0.394579    0.37630805 -1.0233377 ]
#  [ 0.42223567 -0.7540274   0.6644344  -0.9110199   0.17066361 -0.73451895
#   -1.0199261  -0.6488958  -0.08137954  0.56931585]
#  [-0.13323723  1.817549    0.21059434  0.176213   -0.3359472   0.18175077
#   -0.40902463  1.3279301   0.3467392  -0.30059293]]
# tensor: TemporalFusionTransformer/time_distributed_92/bias (float32) [3]
# [0.2844405  0.2755216  0.27589563]
# tensor: TemporalFusionTransformer/time_distributed_92/kernel (float32) [10, 3]
# [[-0.07959978  0.03847392  0.10200138]
#  [-0.02626742 -0.01803547  0.01939364]
#  [-0.25098747  0.11923827  0.12913856]
#  [-0.3755385  -0.28621373 -0.28835014]
#  [-0.44098607 -0.35905373 -0.35664728]
#  [-0.08012518 -0.07359219 -0.01642101]
#  [ 0.40940985  0.45390427  0.45963258]
#  [ 0.36317894  0.42095852  0.4252604 ]
#  [-0.24568096 -0.23320508 -0.21051544]
#  [-0.24626558  0.11836307  0.13416824]]
# # Total number of params: 16948
# Done.
# Computing best validation loss
#                        Datetime      Open  ...       RSI       ATR
# 2340  2022-05-24 09:00:00+02:00 -0.758724  ... -0.052977 -0.556454
# 2341  2022-05-24 10:00:00+02:00 -0.759475  ... -0.107669 -0.563090
# 2342  2022-05-24 11:00:00+02:00 -0.759775  ...  0.367296 -0.537175
# 2343  2022-05-24 12:00:00+02:00 -0.754218  ...  0.306356 -0.565385
# 2344  2022-05-24 13:00:00+02:00 -0.754519  ...  0.150656 -0.571383
# ...                         ...       ...  ...       ...       ...
# 3541  2022-11-25 13:00:00+01:00 -0.998856  ...  0.500922 -0.703303
# 3542  2022-11-25 14:00:00+01:00 -1.000208  ...  0.204892 -0.710142
# 3543  2022-11-25 15:00:00+01:00 -1.002010  ...  0.121702 -0.721246
# 3544  2022-11-25 16:00:00+01:00 -1.002610  ...  0.434943 -0.727991
# 3545  2022-11-25 17:00:00+01:00 -0.999907  ...  0.506002 -0.746136
#
# [24120 rows x 19 columns]
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#                        Datetime      Open  ...       RSI       ATR
# 2340  2022-05-24 09:00:00+02:00 -0.758724  ... -0.052977 -0.556454
# 2341  2022-05-24 10:00:00+02:00 -0.759475  ... -0.107669 -0.563090
# 2342  2022-05-24 11:00:00+02:00 -0.759775  ...  0.367296 -0.537175
# 2343  2022-05-24 12:00:00+02:00 -0.754218  ...  0.306356 -0.565385
# 2344  2022-05-24 13:00:00+02:00 -0.754519  ...  0.150656 -0.571383
# ...                         ...       ...  ...       ...       ...
# 3541  2022-11-25 13:00:00+01:00 -0.998856  ...  0.500922 -0.703303
# 3542  2022-11-25 14:00:00+01:00 -1.000208  ...  0.204892 -0.710142
# 3543  2022-11-25 15:00:00+01:00 -1.002010  ...  0.121702 -0.721246
# 3544  2022-11-25 16:00:00+01:00 -1.002610  ...  0.434943 -0.727991
# 3545  2022-11-25 17:00:00+01:00 -0.999907  ...  0.506002 -0.746136
#
# [24120 rows x 19 columns]
# /opt/conda/lib/python3.10/site-packages/keras/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# Computing test loss
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#                        Datetime      Open  ...       RSI       ATR
# 3546  2022-11-28 09:00:00+01:00 -0.808432  ... -0.124246 -0.449263
# 3547  2022-11-28 10:00:00+01:00 -0.804377  ... -0.575754 -0.448110
# 3548  2022-11-28 11:00:00+01:00 -0.810084  ... -0.368312 -0.456545
# 3549  2022-11-28 12:00:00+01:00 -0.807531  ... -0.312338 -0.466753
# 3550  2022-11-28 13:00:00+01:00 -0.807381  ... -0.460746 -0.479796
# ...                         ...       ...  ...       ...       ...
# 4686  2023-05-30 09:00:00+02:00 -1.101652  ... -0.120512 -0.868499
# 4687  2023-05-30 10:00:00+02:00 -1.100000  ... -0.355074 -0.861160
# 4688  2023-05-30 11:00:00+02:00 -1.101201  ... -0.497111 -0.869795
# 4689  2023-05-30 12:00:00+02:00 -1.101952  ... -0.540577 -0.879001
# 4690  2023-05-30 13:00:00+02:00 -1.102253  ... -0.225092 -0.885173
#
# [22881 rows x 19 columns]
# /opt/conda/lib/python3.10/site-packages/keras/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# Training completed @ 2023-07-20 18:49:20.732258
# Best validation loss = 0.06389904384413048
# Params:
# dropout_rate  =  0.1
# hidden_layer_size  =  10
# learning_rate  =  0.01
# max_gradient_norm  =  1.0
# minibatch_size  =  64
# model_folder  =  output/saved_models/ohlc/fixed
# num_heads  =  1
# stack_size  =  1
# total_time_steps  =  257
# num_encoder_steps  =  252
# num_epochs  =  100
# early_stopping_patience  =  5
# multiprocessing_workers  =  5
# column_definition  =  [('Symbol', <DataTypes.CATEGORICAL: 1>, <InputTypes.ID: 4>), ('Datetime', <DataTypes.DATE: 2>, <InputTypes.TIME: 5>), ('Open', <DataTypes.REAL_VALUED: 0>, <InputTypes.OBSERVED_INPUT: 1>), ('High', <DataTypes.REAL_VALUED: 0>, <InputTypes.OBSERVED_INPUT: 1>), ('Low', <DataTypes.REAL_VALUED: 0>, <InputTypes.OBSERVED_INPUT: 1>), ('HighLowDifference', <DataTypes.REAL_VALUED: 0>, <InputTypes.OBSERVED_INPUT: 1>), ('OpenCloseDifference', <DataTypes.REAL_VALUED: 0>, <InputTypes.OBSERVED_INPUT: 1>), ('ATR', <DataTypes.REAL_VALUED: 0>, <InputTypes.OBSERVED_INPUT: 1>), ('RSI', <DataTypes.REAL_VALUED: 0>, <InputTypes.OBSERVED_INPUT: 1>), ('Close', <DataTypes.REAL_VALUED: 0>, <InputTypes.TARGET: 0>), ('HoursFromStart', <DataTypes.REAL_VALUED: 0>, <InputTypes.KNOWN_INPUT: 2>), ('HourOfDay', <DataTypes.CATEGORICAL: 1>, <InputTypes.KNOWN_INPUT: 2>), ('DayOfWeek', <DataTypes.CATEGORICAL: 1>, <InputTypes.KNOWN_INPUT: 2>), ('StatSymbol', <DataTypes.CATEGORICAL: 1>, <InputTypes.STATIC_INPUT: 3>)]
# input_size  =  12
# output_size  =  1
# category_counts  =  [10, 5, 20]
# input_obs_loc  =  [7]
# static_input_loc  =  [11]
# known_regular_inputs  =  [8]
# known_categorical_inputs  =  [0, 1, 2]
# Normalised Quantile Loss for Test Data: P50=0.07721043966003949, P90=0.06796583852393745
# NAN
# [-1.2144539166430168, -1.2132674968075403, -1.2129671466014782, -1.2128169643373625, -1.2155051638474876]
